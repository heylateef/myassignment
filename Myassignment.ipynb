# %% [markdown]
# reate one variable containing following type of data:

# %%
var1="Syed Rahman ur Lateef"
var2=["Lateef",20,30,60,90]
var3=1.55
var=(30,50,60,0,"lateef")
print(var1)
print(var2)
print(var3)
print(var)

# %% [markdown]
# iven are some following variables containing data:

# %%
var4 = ' '
var5 = '[ DS , ML , Python]'
var6 = [ 'DS','Ml','Python' ]
var7 = 1.
#What will be the data type of the above given variable.
#Answer
print(type(var4))
print(type(var5))
print(type(var6))
print(type(var7))
#Create a list of length 10 of your choice containing multiple types of data. Using for loop print the element and its data type.
l=[10,30,"Lateef",6.23,50,60,True,90.5,"Rahman"]
for i in l :
    print(type(i))
for i in l:
    print(i)
# Create a list containing 25 int type data. Using for loop and if-else condition print if the element is divisible by 3 or not.
list=[60,70,3,10,9,15,33,90,100,6,9,4,8,10,14,18,5,25,30,105,111,22]
for i in list:
    if i % 3 ==0:
        print(i)
#Using a while loop, verify if the number A is purely divisible by number B and if so then how many times it can be divisible.
a = int(input("Enter the number for A:"))
b = int(input('Enter the number for B:'))
count =0
while a%b==0:
    count=+1
    a=a//b
if count>0:
    print("A is divisible B",count,"times")
else:
    print("It is not divisible by b")
#What do you understand about mutable and immutable data types? Give examples for both showing this property.
# immutable is we cannot change the value of data type or data like string
#Exampple String
str_A="Syed Rahman ur Lateef"  
print(str_A)
#we cannot change string value because it is immutable
#Mutable means we can change it's data after assigning aslo like list
list_A =[30,40,50,"Lateef",100,50]
list_A.append(60)
print(list_A)
#here we added one integer for the list using APPEND Function
